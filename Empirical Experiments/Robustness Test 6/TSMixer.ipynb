# %% [markdown]
# # TSMixer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import time
from random import randrange
import tensorflow as tf
#from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading Data

# %%
    filepath = ("Commodities Daily Realized Covariance (Neural).xlsx")

    df_raw = pd.read_excel(filepath, sheet_name= "Vol")
    df = df_raw.set_index('Date')

    # split train/valid/test
    n = len(df)
    train_end = int(n * 0.7)-5
    val_end = int(n * 0.7)+5
    test_end = n

test_true=df[val_end - 21 : test_end]
test_true=test_true.iloc[21:]

# %% [markdown]
# # Test

# %%
class DataLoader:

  def __init__(self, batch_size, seq_len, pred_len):
    self.batch_size = batch_size
    self.seq_len = seq_len
    self.pred_len = pred_len
    self.target_slice = slice(0, None)

    self._read_data()

  def _read_data(self):

    filepath = ("Commodities Daily Realized Covariance (Neural).xlsx")

    df_raw = pd.read_excel(filepath, sheet_name= "Vol")
    df = df_raw.set_index('Date')

    # split train/valid/test
    n = len(df)
    train_end = int(n * 0.7)-5
    val_end = int(n * 0.7)+5
    test_end = n

    train_df = df[:train_end]
    val_df = df[train_end - self.seq_len : val_end]
    test_df = df[val_end - self.seq_len : test_end]

    # standardize by training set
    self.scaler = StandardScaler()
    self.scaler.fit(train_df.values)

    def scale_df(df, scaler):
      data = scaler.transform(df.values)
      return pd.DataFrame(data, index=df.index, columns=df.columns)

    self.train_df = scale_df(train_df, self.scaler)
    self.val_df = scale_df(val_df, self.scaler)
    self.test_df = scale_df(test_df, self.scaler)
    self.n_feature = self.train_df.shape[-1]

  def _split_window(self, data):
    inputs = data[:, : self.seq_len, :]
    labels = data[:, self.seq_len :, self.target_slice]

    inputs.set_shape([None, self.seq_len, None])
    labels.set_shape([None, self.pred_len, None])
    return inputs, labels

  def _make_dataset(self, data, shuffle=False):
    data = np.array(data, dtype=np.float32)
    ds = tf.keras.utils.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=(self.seq_len + self.pred_len),
        sequence_stride=1,
        shuffle=shuffle,
        batch_size=self.batch_size,
    )
    ds = ds.map(self._split_window)
    return ds

  def inverse_transform(self, data):
    return self.scaler.inverse_transform(data)

  def get_train(self, shuffle=True):
    return self._make_dataset(self.train_df, shuffle=shuffle)

  def get_val(self):
    return self._make_dataset(self.val_df, shuffle=False)

  def get_test(self):
    return self._make_dataset(self.test_df, shuffle=False)

  def make_forecast(self, model):
    test_data = self.test_df.values
    predictions = []

    for i in range(0, len(test_data) - self.seq_len, self.pred_len):
        input_seq = test_data[i:i + self.seq_len]
        input_seq = input_seq.reshape((1, self.seq_len, -1))

            # Make prediction and reshape output
        pred = model.predict(input_seq)
        pred = pred.reshape(self.pred_len, -1)

        predictions.append(pred)

        # Concatenate all predictions
    predictions = np.concatenate(predictions, axis=0)
    return predictions

# %%
  data_loader = DataLoader(batch_size=32, seq_len=21, pred_len=1)

  train_data = data_loader.get_train()
  val_data = data_loader.get_val()
  test_data = data_loader.get_test()

  def res_block(inputs, ff_dim):

    norm = layers.BatchNormalization

    # Time mixing
    x = norm(axis=[-2, -1])(inputs)
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
    x = layers.Dense(x.shape[-1], activation='relu')(x)
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    res = x + inputs

    # Feature mixing
    x = norm(axis=[-2, -1])(res)
    x = layers.Dense(ff_dim, activation='relu')(x)  # [Batch, Input Length, FF_Dim]
    x = layers.Dropout(0.7)(x)
    x = layers.Dense(inputs.shape[-1])(x)  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    return x + res

  def build_model(
      input_shape,
      pred_len,
      n_block,
      ff_dim,
      target_slice,
  ):

    inputs = tf.keras.Input(shape=input_shape)
    x = inputs  # [Batch, Input Length, Channel]
    for _ in range(n_block):
      x = res_block(x, ff_dim)

    if target_slice:
      x = x[:, :, target_slice]

    # Temporal projection
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
    x = layers.Dense(pred_len)(x)  # [Batch, Channel, Output Length]
    outputs = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Output Length, Channel])

    return tf.keras.Model(inputs, outputs)

  model = build_model(
      input_shape=(21, data_loader.n_feature),
      pred_len=1,
      n_block=2,
      ff_dim=220,
      target_slice=data_loader.target_slice
  )

  tf.keras.utils.set_random_seed(89102543)

  optimizer = tf.keras.optimizers.Adam(0.0005)

  model.compile(optimizer, loss='mse', metrics=['mae', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error'])

  #early_stop_callback = tf.keras.callbacks.EarlyStopping(
  #    monitor='val_loss',
  #    patience=140
  #)

  start_training_time = time.time()

  history = model.fit(
      train_data,
      epochs= 168 #accounting for early stop
      #validation_data=val_data,
     # callbacks=[early_stop_callback]
  )

  end_training_time = time.time()
  elasped_training_time = end_training_time - start_training_time
  print(f'Training finished in {elasped_training_time} seconds')
# Out:
# Epoch 1/168
# 76/76 [==============================] - 2s 6ms/step - loss: 6.8715 - mae: 1.9463 - mean_absolute_percentage_error: 1690.1307 - mean_squared_logarithmic_error: 0.4939
# Epoch 2/168
# 76/76 [==============================] - 0s 6ms/step - loss: 4.0213 - mae: 1.4918 - mean_absolute_percentage_error: 1497.8060 - mean_squared_logarithmic_error: 0.3568
# Epoch 3/168
# 76/76 [==============================] - 0s 6ms/step - loss: 2.9243 - mae: 1.2544 - mean_absolute_percentage_error: 1882.2207 - mean_squared_logarithmic_error: 0.2916
# Epoch 4/168
# 76/76 [==============================] - 0s 6ms/step - loss: 2.2932 - mae: 1.1075 - mean_absolute_percentage_error: 1069.9672 - mean_squared_logarithmic_error: 0.2520
# Epoch 5/168
# 76/76 [==============================] - 0s 6ms/step - loss: 1.9361 - mae: 1.0091 - mean_absolute_percentage_error: 1049.6222 - mean_squared_logarithmic_error: 0.2273
# Epoch 6/168
# 76/76 [==============================] - 0s 6ms/step - loss: 1.6435 - mae: 0.9276 - mean_absolute_percentage_error: 927.5650 - mean_squared_logarithmic_error: 0.2051
# Epoch 7/168
# 76/76 [==============================] - 0s 5ms/step - loss: 1.4163 - mae: 0.8594 - mean_absolute_percentage_error: 676.1852 - mean_squared_logarithmic_error: 0.1862
# Epoch 8/168
# 76/76 [==============================] - 0s 6ms/step - loss: 1.2691 - mae: 0.8041 - mean_absolute_percentage_error: 622.1727 - mean_squared_logarithmic_error: 0.1722
# Epoch 9/168
# 76/76 [==============================] - 0s 6ms/step - loss: 1.1501 - mae: 0.7672 - mean_absolute_percentage_error: 693.6668 - mean_squared_logarithmic_error: 0.1604
# Epoch 10/168
# 76/76 [==============================] - 0s 6ms/step - loss: 1.0710 - mae: 0.7284 - mean_absolute_percentage_error: 664.0239 - mean_squared_logarithmic_error: 0.1513
# Epoch 11/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0
168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4547 - mae: 0.4171 - mean_absolute_percentage_error: 480.5674 - mean_squared_logarithmic_error: 0.0681
# Epoch 153/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4516 - mae: 0.4172 - mean_absolute_percentage_error: 476.3792 - mean_squared_logarithmic_error: 0.0679
# Epoch 154/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4535 - mae: 0.4179 - mean_absolute_percentage_error: 477.0883 - mean_squared_logarithmic_error: 0.0681
# Epoch 155/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4531 - mae: 0.4171 - mean_absolute_percentage_error: 516.4355 - mean_squared_logarithmic_error: 0.0681
# Epoch 156/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4505 - mae: 0.4173 - mean_absolute_percentage_error: 497.2010 - mean_squared_logarithmic_error: 0.0676
# Epoch 157/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4533 - mae: 0.4176 - mean_absolute_percentage_error: 498.2738 - mean_squared_logarithmic_error: 0.0680
# Epoch 158/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4537 - mae: 0.4174 - mean_absolute_percentage_error: 482.3752 - mean_squared_logarithmic_error: 0.0681
# Epoch 159/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4527 - mae: 0.4178 - mean_absolute_percentage_error: 491.6847 - mean_squared_logarithmic_error: 0.0681
# Epoch 160/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4520 - mae: 0.4178 - mean_absolute_percentage_error: 490.8239 - mean_squared_logarithmic_error: 0.0677
# Epoch 161/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4525 - mae: 0.4180 - mean_absolute_percentage_error: 525.7346 - mean_squared_logarithmic_error: 0.0679
# Epoch 162/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4513 - mae: 0.4179 - mean_absolute_percentage_error: 469.6602 - mean_squared_logarithmic_error: 0.0674
# Epoch 163/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4524 - mae: 0.4170 - mean_absolute_percentage_error: 497.7434 - mean_squared_logarithmic_error: 0.0679
# Epoch 164/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4521 - mae: 0.4180 - mean_absolute_percentage_error: 511.9122 - mean_squared_logarithmic_error: 0.0676
# Epoch 165/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4534 - mae: 0.4178 - mean_absolute_percentage_error: 467.0296 - mean_squared_logarithmic_error: 0.0678
# Epoch 166/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4532 - mae: 0.4175 - mean_absolute_percentage_error: 515.7446 - mean_squared_logarithmic_error: 0.0676
# Epoch 167/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4537 - mae: 0.4178 - mean_absolute_percentage_error: 482.9932 - mean_squared_logarithmic_error: 0.0677
# Epoch 168/168
# 76/76 [==============================] - 0s 6ms/step - loss: 0.4537 - mae: 0.4182 - mean_absolute_percentage_error: 488.7097 - mean_squared_logarithmic_error: 0.0678
# Training finished in 79.56682300567627 seconds

# %%
columns=df.columns
predictions = model.predict(test_data)
scaled_preds = predictions
scaled_preds=scaled_preds.reshape(scaled_preds.shape[0], scaled_preds.shape[2])
scaled_preds.shape
preds = data_loader.inverse_transform(scaled_preds)
RMSE_test=np.sqrt(((test_true.iloc[:]-preds)**2).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]])))
MAE_test=((abs(test_true.iloc[:]-preds)).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]])))
MAPE_test=((abs(test_true.iloc[:]-preds)/test_true.iloc[:]).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]])))
QLIKE_test=((test_true.iloc[:]/preds)-np.log(test_true.iloc[:]/preds)-1).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]]))
print(RMSE_test)
print(MAE_test)
print(MAPE_test)
print(QLIKE_test)
# Out:
# 33/33 [==============================] - 0s 4ms/step
# 0.003926703735460241
# 0.002641181787152314
# 0.19311031151543268
# 0.02870360864664359

# %%
test_true.iloc[:]=preds
test_true.to_excel("TSMixer forecasts.xlsx")
