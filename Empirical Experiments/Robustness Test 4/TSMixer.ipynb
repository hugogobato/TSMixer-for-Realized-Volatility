# %% [markdown]
# # TSMixer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import time
from random import randrange
import tensorflow as tf
#from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading Data

# %%
    filepath = ("Stock Indexes Daily Realized Covariance (Neural).xlsx")

    df_raw = pd.read_excel(filepath, sheet_name= "Vol (Neural)")
    df = df_raw.set_index('Date')

    # split train/valid/test
    n = len(df)
    train_end = int(n * 0.7)-5
    val_end = int(n * 0.7)+5
    test_end = n

test_true=df[val_end - 21 : test_end]
test_true=test_true.iloc[21:]

# %% [markdown]
# # Test

# %%
class DataLoader:

  def __init__(self, batch_size, seq_len, pred_len):
    self.batch_size = batch_size
    self.seq_len = seq_len
    self.pred_len = pred_len
    self.target_slice = slice(0, None)

    self._read_data()

  def _read_data(self):

    filepath = ("Stock Indexes Daily Realized Covariance (Neural).xlsx")

    df_raw = pd.read_excel(filepath, sheet_name= "Vol (Neural)")
    df = df_raw.set_index('Date')

    # split train/valid/test
    n = len(df)
    train_end = int(n * 0.7)-5
    val_end = int(n * 0.7)+5
    test_end = n

    train_df = df[:train_end]
    val_df = df[train_end - self.seq_len : val_end]
    test_df = df[val_end - self.seq_len : test_end]

    # standardize by training set
    self.scaler = StandardScaler()
    self.scaler.fit(train_df.values)

    def scale_df(df, scaler):
      data = scaler.transform(df.values)
      return pd.DataFrame(data, index=df.index, columns=df.columns)

    self.train_df = scale_df(train_df, self.scaler)
    self.val_df = scale_df(val_df, self.scaler)
    self.test_df = scale_df(test_df, self.scaler)
    self.n_feature = self.train_df.shape[-1]

  def _split_window(self, data):
    inputs = data[:, : self.seq_len, :]
    labels = data[:, self.seq_len :, self.target_slice]

    inputs.set_shape([None, self.seq_len, None])
    labels.set_shape([None, self.pred_len, None])
    return inputs, labels

  def _make_dataset(self, data, shuffle=False):
    data = np.array(data, dtype=np.float32)
    ds = tf.keras.utils.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=(self.seq_len + self.pred_len),
        sequence_stride=1,
        shuffle=shuffle,
        batch_size=self.batch_size,
    )
    ds = ds.map(self._split_window)
    return ds

  def inverse_transform(self, data):
    return self.scaler.inverse_transform(data)

  def get_train(self, shuffle=True):
    return self._make_dataset(self.train_df, shuffle=shuffle)

  def get_val(self):
    return self._make_dataset(self.val_df, shuffle=False)

  def get_test(self):
    return self._make_dataset(self.test_df, shuffle=False)

  def make_forecast(self, model):
    test_data = self.test_df.values
    predictions = []

    for i in range(0, len(test_data) - self.seq_len, self.pred_len):
        input_seq = test_data[i:i + self.seq_len]
        input_seq = input_seq.reshape((1, self.seq_len, -1))

            # Make prediction and reshape output
        pred = model.predict(input_seq)
        pred = pred.reshape(self.pred_len, -1)

        predictions.append(pred)

        # Concatenate all predictions
    predictions = np.concatenate(predictions, axis=0)
    return predictions

# %%
  data_loader = DataLoader(batch_size=32, seq_len=21, pred_len=1)

  train_data = data_loader.get_train()
  val_data = data_loader.get_val()
  test_data = data_loader.get_test()

  def res_block(inputs, ff_dim):

    norm = layers.BatchNormalization

    # Time mixing
    x = norm(axis=[-2, -1])(inputs)
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
    x = layers.Dense(x.shape[-1], activation='relu')(x)
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    res = x + inputs

    # Feature mixing
    x = norm(axis=[-2, -1])(res)
    x = layers.Dense(ff_dim, activation='relu')(x)  # [Batch, Input Length, FF_Dim]
    x = layers.Dropout(0.7)(x)
    x = layers.Dense(inputs.shape[-1])(x)  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    return x + res

  def build_model(
      input_shape,
      pred_len,
      n_block,
      ff_dim,
      target_slice,
  ):

    inputs = tf.keras.Input(shape=input_shape)
    x = inputs  # [Batch, Input Length, Channel]
    for _ in range(n_block):
      x = res_block(x, ff_dim)

    if target_slice:
      x = x[:, :, target_slice]

    # Temporal projection
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
    x = layers.Dense(pred_len)(x)  # [Batch, Channel, Output Length]
    outputs = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Output Length, Channel])

    return tf.keras.Model(inputs, outputs)

  model = build_model(
      input_shape=(21, data_loader.n_feature),
      pred_len=1,
      n_block=2,
      ff_dim=220,
      target_slice=data_loader.target_slice
  )

  tf.keras.utils.set_random_seed(89102543)

  optimizer = tf.keras.optimizers.Adam(0.0005)

  model.compile(optimizer, loss='mse', metrics=['mae', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error'])

  #early_stop_callback = tf.keras.callbacks.EarlyStopping(
  #    monitor='val_loss',
  #    patience=140
  #)

  start_training_time = time.time()

  history = model.fit(
      train_data,
      epochs= 168 #accounting for early stop
      #validation_data=val_data,
     # callbacks=[early_stop_callback]
  )

  end_training_time = time.time()
  elasped_training_time = end_training_time - start_training_time
  print(f'Training finished in {elasped_training_time} seconds')
# Out:
# Epoch 1/168
# 71/71 [==============================] - 2s 6ms/step - loss: 10.7673 - mae: 2.0668 - mean_absolute_percentage_error: 3194.1436 - mean_squared_logarithmic_error: 0.4581
# Epoch 2/168
# 71/71 [==============================] - 0s 6ms/step - loss: 5.6761 - mae: 1.5977 - mean_absolute_percentage_error: 4020.1697 - mean_squared_logarithmic_error: 0.3770
# Epoch 3/168
# 71/71 [==============================] - 0s 5ms/step - loss: 4.4558 - mae: 1.4053 - mean_absolute_percentage_error: 1491.1805 - mean_squared_logarithmic_error: 0.3250
# Epoch 4/168
# 71/71 [==============================] - 0s 6ms/step - loss: 3.5900 - mae: 1.2618 - mean_absolute_percentage_error: 1726.1859 - mean_squared_logarithmic_error: 0.2837
# Epoch 5/168
# 71/71 [==============================] - 0s 5ms/step - loss: 3.0044 - mae: 1.1487 - mean_absolute_percentage_error: 1953.9833 - mean_squared_logarithmic_error: 0.2581
# Epoch 6/168
# 71/71 [==============================] - 0s 6ms/step - loss: 2.6289 - mae: 1.0863 - mean_absolute_percentage_error: 1232.2043 - mean_squared_logarithmic_error: 0.2406
# Epoch 7/168
# 71/71 [==============================] - 0s 6ms/step - loss: 2.2606 - mae: 0.9979 - mean_absolute_percentage_error: 1521.0531 - mean_squared_logarithmic_error: 0.2169
# Epoch 8/168
# 71/71 [==============================] - 0s 6ms/step - loss: 1.9954 - mae: 0.9340 - mean_absolute_percentage_error: 912.8294 - mean_squared_logarithmic_error: 0.2037
# Epoch 9/168
# 71/71 [==============================] - 0s 6ms/step - loss: 1.7838 - mae: 0.8745 - mean_absolute_percentage_error: 1461.4167 - mean_squared_logarithmic_error: 0.1842
168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3280 - mae: 0.3204 - mean_absolute_percentage_error: 314.9548 - mean_squared_logarithmic_error: 0.0408
# Epoch 154/168
# 71/71 [==============================] - 1s 7ms/step - loss: 0.3216 - mae: 0.3190 - mean_absolute_percentage_error: 312.3983 - mean_squared_logarithmic_error: 0.0405
# Epoch 155/168
# 71/71 [==============================] - 1s 7ms/step - loss: 0.3246 - mae: 0.3195 - mean_absolute_percentage_error: 322.0861 - mean_squared_logarithmic_error: 0.0403
# Epoch 156/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3262 - mae: 0.3185 - mean_absolute_percentage_error: 343.6580 - mean_squared_logarithmic_error: 0.0408
# Epoch 157/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3264 - mae: 0.3186 - mean_absolute_percentage_error: 300.7401 - mean_squared_logarithmic_error: 0.0407
# Epoch 158/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3299 - mae: 0.3199 - mean_absolute_percentage_error: 296.4407 - mean_squared_logarithmic_error: 0.0408
# Epoch 159/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3245 - mae: 0.3204 - mean_absolute_percentage_error: 332.8830 - mean_squared_logarithmic_error: 0.0406
# Epoch 160/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3200 - mae: 0.3191 - mean_absolute_percentage_error: 372.2995 - mean_squared_logarithmic_error: 0.0404
# Epoch 161/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3288 - mae: 0.3200 - mean_absolute_percentage_error: 308.9980 - mean_squared_logarithmic_error: 0.0407
# Epoch 162/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3236 - mae: 0.3187 - mean_absolute_percentage_error: 307.3607 - mean_squared_logarithmic_error: 0.0402
# Epoch 163/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3262 - mae: 0.3197 - mean_absolute_percentage_error: 349.6185 - mean_squared_logarithmic_error: 0.0408
# Epoch 164/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3238 - mae: 0.3198 - mean_absolute_percentage_error: 301.4371 - mean_squared_logarithmic_error: 0.0407
# Epoch 165/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3252 - mae: 0.3195 - mean_absolute_percentage_error: 291.0931 - mean_squared_logarithmic_error: 0.0407
# Epoch 166/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3242 - mae: 0.3170 - mean_absolute_percentage_error: 318.1783 - mean_squared_logarithmic_error: 0.0405
# Epoch 167/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3181 - mae: 0.3169 - mean_absolute_percentage_error: 321.6006 - mean_squared_logarithmic_error: 0.0400
# Epoch 168/168
# 71/71 [==============================] - 0s 6ms/step - loss: 0.3235 - mae: 0.3192 - mean_absolute_percentage_error: 377.5489 - mean_squared_logarithmic_error: 0.0407
# Training finished in 80.6670572757721 seconds

# %%
columns=df.columns
predictions = model.predict(test_data)
scaled_preds = predictions
scaled_preds=scaled_preds.reshape(scaled_preds.shape[0], scaled_preds.shape[2])
scaled_preds.shape
preds = data_loader.inverse_transform(scaled_preds)
RMSE_test=np.sqrt(((test_true.iloc[:]-preds)**2).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true["AU200_AUD"])))
MAE_test=((abs(test_true.iloc[:]-preds)).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true["AU200_AUD"])))
MAPE_test=((abs(test_true.iloc[:]-preds)/test_true.iloc[:]).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true["AU200_AUD"])))
QLIKE_test=((test_true.iloc[:]/preds)-np.log(test_true.iloc[:]/preds)-1).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true["AU200_AUD"]))
print(RMSE_test)
print(MAE_test)
print(MAPE_test)
print(QLIKE_test)
# Out:
# 31/31 [==============================] - 0s 2ms/step
# 0.0031796529473768482
# 0.0017376227009325896
# 0.22739078334994997
# 0.038752229005069465

# %%
test_true.iloc[:]=preds
test_true.to_excel("TSMixer forecasts.xlsx")
