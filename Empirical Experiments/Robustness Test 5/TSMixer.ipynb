# %% [markdown]
# # TSMixer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import time
from random import randrange
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading Data

# %%
    filepath = ("FX Daily Realized Covariance (Neural).xlsx")

    df_raw = pd.read_excel(filepath, sheet_name= "Vol (Neural)")
    df = df_raw.set_index('Date')

    # split train/valid/test
    n = len(df)
    train_end = int(n * 0.7)-5
    val_end = int(n * 0.7)+5
    test_end = n

test_true=df[val_end - 21 : test_end]
test_true=test_true.iloc[21:]

# %% [markdown]
# # Test

# %%
class DataLoader:

  def __init__(self, batch_size, seq_len, pred_len):
    self.batch_size = batch_size
    self.seq_len = seq_len
    self.pred_len = pred_len
    self.target_slice = slice(0, None)

    self._read_data()

  def _read_data(self):

    filepath = ("FX Daily Realized Covariance (Neural).xlsx")

    df_raw = pd.read_excel(filepath, sheet_name= "Vol (Neural)")
    df = df_raw.set_index('Date')

    # split train/valid/test
    n = len(df)
    train_end = int(n * 0.7)-5
    val_end = int(n * 0.7)+5
    test_end = n

    train_df = df[:train_end]
    val_df = df[train_end - self.seq_len : val_end]
    test_df = df[val_end - self.seq_len : test_end]

    # standardize by training set
    self.scaler = StandardScaler()
    self.scaler.fit(train_df.values)

    def scale_df(df, scaler):
      data = scaler.transform(df.values)
      return pd.DataFrame(data, index=df.index, columns=df.columns)

    self.train_df = scale_df(train_df, self.scaler)
    self.val_df = scale_df(val_df, self.scaler)
    self.test_df = scale_df(test_df, self.scaler)
    self.n_feature = self.train_df.shape[-1]

  def _split_window(self, data):
    inputs = data[:, : self.seq_len, :]
    labels = data[:, self.seq_len :, self.target_slice]

    inputs.set_shape([None, self.seq_len, None])
    labels.set_shape([None, self.pred_len, None])
    return inputs, labels

  def _make_dataset(self, data, shuffle=False):
    data = np.array(data, dtype=np.float32)
    ds = tf.keras.utils.timeseries_dataset_from_array(
        data=data,
        targets=None,
        sequence_length=(self.seq_len + self.pred_len),
        sequence_stride=1,
        shuffle=shuffle,
        batch_size=self.batch_size,
    )
    ds = ds.map(self._split_window)
    return ds

  def inverse_transform(self, data):
    return self.scaler.inverse_transform(data)

  def get_train(self, shuffle=True):
    return self._make_dataset(self.train_df, shuffle=shuffle)

  def get_val(self):
    return self._make_dataset(self.val_df, shuffle=False)

  def get_test(self):
    return self._make_dataset(self.test_df, shuffle=False)

  def make_forecast(self, model):
    test_data = self.test_df.values
    predictions = []

    for i in range(0, len(test_data) - self.seq_len, self.pred_len):
        input_seq = test_data[i:i + self.seq_len]
        input_seq = input_seq.reshape((1, self.seq_len, -1))

            # Make prediction and reshape output
        pred = model.predict(input_seq)
        pred = pred.reshape(self.pred_len, -1)

        predictions.append(pred)

        # Concatenate all predictions
    predictions = np.concatenate(predictions, axis=0)
    return predictions

# %%
  data_loader = DataLoader(batch_size=32, seq_len=21, pred_len=1)

  train_data = data_loader.get_train()
  val_data = data_loader.get_val()
  test_data = data_loader.get_test()

  def res_block(inputs, ff_dim):

    norm = layers.BatchNormalization

    # Time mixing
    x = norm(axis=[-2, -1])(inputs)
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
    x = layers.Dense(x.shape[-1], activation='relu')(x)
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    res = x + inputs

    # Feature mixing
    x = norm(axis=[-2, -1])(res)
    x = layers.Dense(ff_dim, activation='relu')(x)  # [Batch, Input Length, FF_Dim]
    x = layers.Dropout(0.7)(x)
    x = layers.Dense(inputs.shape[-1])(x)  # [Batch, Input Length, Channel]
    x = layers.Dropout(0.7)(x)
    return x + res

  def build_model(
      input_shape,
      pred_len,
      n_block,
      ff_dim,
      target_slice,
  ):

    inputs = tf.keras.Input(shape=input_shape)
    x = inputs  # [Batch, Input Length, Channel]
    for _ in range(n_block):
      x = res_block(x, ff_dim)

    if target_slice:
      x = x[:, :, target_slice]

    # Temporal projection
    x = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Channel, Input Length]
    x = layers.Dense(pred_len)(x)  # [Batch, Channel, Output Length]
    outputs = tf.transpose(x, perm=[0, 2, 1])  # [Batch, Output Length, Channel])

    return tf.keras.Model(inputs, outputs)

  model = build_model(
      input_shape=(21, data_loader.n_feature),
      pred_len=1,
      n_block=2,
      ff_dim=220,
      target_slice=data_loader.target_slice
  )

  tf.keras.utils.set_random_seed(89102543)

  optimizer = tf.keras.optimizers.Adam(0.0005)

  model.compile(optimizer, loss='mse', metrics=['mae', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error'])

  #early_stop_callback = tf.keras.callbacks.EarlyStopping(
  #    monitor='val_loss',
  #    patience=140
  #)

  start_training_time = time.time()

  history = model.fit(
      train_data,
      epochs= 168 #accounting for early stop
      #validation_data=val_data,
     # callbacks=[early_stop_callback]
  )

  end_training_time = time.time()
  elasped_training_time = end_training_time - start_training_time
  print(f'Training finished in {elasped_training_time} seconds')
# Out:
# Epoch 1/168
# 102/102 [==============================] - 7s 23ms/step - loss: 6.5535 - mae: 1.7817 - mean_absolute_percentage_error: 1594.8325 - mean_squared_logarithmic_error: 0.4744
# Epoch 2/168
# 102/102 [==============================] - 1s 14ms/step - loss: 3.5973 - mae: 1.3419 - mean_absolute_percentage_error: 1257.6553 - mean_squared_logarithmic_error: 0.3088
# Epoch 3/168
# 102/102 [==============================] - 1s 14ms/step - loss: 2.4567 - mae: 1.1084 - mean_absolute_percentage_error: 966.7157 - mean_squared_logarithmic_error: 0.2398
# Epoch 4/168
# 102/102 [==============================] - 1s 14ms/step - loss: 1.7962 - mae: 0.9532 - mean_absolute_percentage_error: 783.5590 - mean_squared_logarithmic_error: 0.1935
# Epoch 5/168
# 102/102 [==============================] - 2s 16ms/step - loss: 1.4215 - mae: 0.8426 - mean_absolute_percentage_error: 821.8326 - mean_squared_logarithmic_error: 0.1660
# Epoch 6/168
# 102/102 [==============================] - 2s 22ms/step - loss: 1.1735 - mae: 0.7598 - mean_absolute_percentage_error: 643.2389 - mean_squared_logarithmic_error: 0.1431
# Epoch 7/168
# 102/102 [==============================] - 2s 16ms/step - loss: 0.9973 - mae: 0.7021 - mean_absolute_percentage_error: 594.8907 - mean_squared_logarithmic_error: 0.1292
# Epoch 8/168
# 102/102 [==============================] - 1s 14ms/step - loss: 0.8167 - mae: 0.6367 - mean_absolute_percentage_error: 546.4970 - mean_squared_logarithmic_error: 0.1113
# Epoch 9/168
# 102/102 [==============================] - 1s 14ms/step - loss: 0.7660 - mae: 0.6048 - mean_absolute_percentage_error: 492.1403 - mean_squared_logarithmic_error: 0.1052
# Epoch 10/168
# 102/102 [==============================] - 1s 14ms/step - loss: 0.6957 - mae: 0.5783 - mean_absolute_percentage_error: 427.2695 - mean_squared_logarithmic_error: 0.0993
# Epoch 11/168
# 102/102 [==============================] - 2s 16ms/step - loss: 0.6452 - mae: 0.5513 - mean_absolute_percentage_error: 452.3855 - mean_squared_logarithmic_error: 0.0934
# Epoch 12/168
# 102/102 [==============================] - 2s 21ms/step - loss: 0.5863 - mae: 0.5244 - mean_absolute_percentage_error: 459.6318 - mean_squared_logarithmic_error: 0.0854
# Epoch 13/168
# 102/102 [==============================] - 1s 14ms/step - loss: 0.
168
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2234 - mae: 0.3052 - mean_absolute_percentage_error: 250.1192 - mean_squared_logarithmic_error: 0.0355
# Epoch 156/168
# 102/102 [==============================] - 2s 14ms/step - loss: 0.2217 - mae: 0.3047 - mean_absolute_percentage_error: 245.4805 - mean_squared_logarithmic_error: 0.0350
# Epoch 157/168
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2221 - mae: 0.3050 - mean_absolute_percentage_error: 269.7721 - mean_squared_logarithmic_error: 0.0351
# Epoch 158/168
# 102/102 [==============================] - 2s 14ms/step - loss: 0.2234 - mae: 0.3055 - mean_absolute_percentage_error: 245.5841 - mean_squared_logarithmic_error: 0.0349
# Epoch 159/168
# 102/102 [==============================] - 2s 19ms/step - loss: 0.2212 - mae: 0.3049 - mean_absolute_percentage_error: 253.3953 - mean_squared_logarithmic_error: 0.0350
# Epoch 160/168
# 102/102 [==============================] - 2s 21ms/step - loss: 0.2193 - mae: 0.3033 - mean_absolute_percentage_error: 244.5033 - mean_squared_logarithmic_error: 0.0352
# Epoch 161/168
# 102/102 [==============================] - 1s 14ms/step - loss: 0.2231 - mae: 0.3054 - mean_absolute_percentage_error: 268.7677 - mean_squared_logarithmic_error: 0.0351
# Epoch 162/168
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2221 - mae: 0.3057 - mean_absolute_percentage_error: 270.8726 - mean_squared_logarithmic_error: 0.0353
# Epoch 163/168
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2238 - mae: 0.3048 - mean_absolute_percentage_error: 257.8852 - mean_squared_logarithmic_error: 0.0354
# Epoch 164/168
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2248 - mae: 0.3063 - mean_absolute_percentage_error: 260.9005 - mean_squared_logarithmic_error: 0.0356
# Epoch 165/168
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2226 - mae: 0.3043 - mean_absolute_percentage_error: 259.8268 - mean_squared_logarithmic_error: 0.0353
# Epoch 166/168
# 102/102 [==============================] - 2s 22ms/step - loss: 0.2189 - mae: 0.3035 - mean_absolute_percentage_error: 252.3243 - mean_squared_logarithmic_error: 0.0349
# Epoch 167/168
# 102/102 [==============================] - 2s 14ms/step - loss: 0.2198 - mae: 0.3022 - mean_absolute_percentage_error: 256.8385 - mean_squared_logarithmic_error: 0.0346
# Epoch 168/168
# 102/102 [==============================] - 2s 15ms/step - loss: 0.2236 - mae: 0.3058 - mean_absolute_percentage_error: 263.4367 - mean_squared_logarithmic_error: 0.0354
# Training finished in 385.0496275424957 seconds

# %%
columns=df.columns
predictions = model.predict(test_data)
scaled_preds = predictions
scaled_preds=scaled_preds.reshape(scaled_preds.shape[0], scaled_preds.shape[2])
scaled_preds.shape
preds = data_loader.inverse_transform(scaled_preds)
RMSE_test=np.sqrt(((test_true.iloc[:]-preds)**2).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]])))
MAE_test=((abs(test_true.iloc[:]-preds)).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]])))
MAPE_test=((abs(test_true.iloc[:]-preds)/test_true.iloc[:]).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]])))
QLIKE_test=((test_true.iloc[:]/preds)-np.log(test_true.iloc[:]/preds)-1).sum(axis=1).sum(axis=0)/(len(columns)*len(test_true[columns[0]]))
print(RMSE_test)
print(MAE_test)
print(MAPE_test)
print(QLIKE_test)
# Out:
# 44/44 [==============================] - 1s 13ms/step
# 0.0021393074055310263
# 0.0011580028798779192
# 0.3157385762942376
# 0.0768297424581548

# %%
test_true.iloc[:]=preds
test_true.to_excel("TSMixer forecasts.xlsx")
